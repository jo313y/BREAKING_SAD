# %%
# Load SQL extension
# %load_ext sql

# %% [markdown]
# # Two ways to connect to Postgres
#
# ## #1: os

# %%
# Import dependencies
import os

# %%
# Create string variables
host = "beer.cs95fnnoentc.us-east-2.rds.amazonaws.com"
database = "beer"
user = "postgres"
password = "3406260306"

# %%
# Create connection string
connection_string = f"postgresql://{user}:{password}@{host}/{database}"

# %%
# %sql $connection_string
# Out:
# 'Connected: postgres@beer'

# %%
# Test connection using SQL
# %sql SELECT * FROM full_table LIMIT 10
# Out:
#  * postgresql://postgres:***@beer.cs95fnnoentc.us-east-2.rds.amazonaws.com/beer
# 10 rows affected.
# [(5.0, 47986, 10325, 'Sausa Weizen', 'Hefeweizen', 2.5, 2.0, 1.5, 1.5, 'stcules', 1.5),
#  (6.2, 48213, 10325, 'Red Moon', 'English Strong Ale', 3.0, 2.5, 3.0, 3.0, 'stcules', 3.0),
#  (6.5, 48215, 10325, 'Black Horse Black Beer', 'Foreign / Export Stout', 3.0, 2.5, 3.0, 3.0, 'stcules', 3.0),
#  (5.0, 47969, 10325, 'Sausa Pils', 'German Pilsener', 3.5, 3.0, 3.0, 2.5, 'stcules', 3.0),
#  (7.7, 64883, 1075, 'Cauldron DIPA', 'American Double / Imperial IPA', 4.0, 4.5, 4.0, 4.0, 'johnmichaelsen', 4.5),
#  (4.7, 52159, 1075, 'Caldera Ginger Beer', 'Herbed / Spiced Beer', 3.5, 3.5, 3.0, 3.0, 'oline73', 3.5),
#  (4.7, 52159, 1075, 'Caldera Ginger Beer', 'Herbed / Spiced Beer', 3.5, 3.5, 3.5, 4.0, 'Reidrover', 4.0),
#  (4.7, 52159, 1075, 'Caldera Ginger Beer', 'Herbed / Spiced Beer', 3.5, 2.5, 3.0, 2.0, 'alpinebryant', 3.5),
# ...

# %% [markdown]
# ## #2: sqlalchemy & pandas

# %%
# Import dependencies
from sqlalchemy import create_engine
from sqlalchemy import inspect
import pandas as pd

# %%
# Define the engine
engine = create_engine(connection_string)

# %%
# Get table names
insp = inspect(engine)
insp.get_table_names()
# Out:
# ['full_table', 'review_table']

# %%
full_table_df = pd.read_sql('SELECT * FROM full_table LIMIT 10', engine)

# %%
full_table_df
# Out:
#    beer_abv  beer_beerid  beer_brewerid               beer_name  \
# 0       5.0        47986          10325            Sausa Weizen
# 1       6.2        48213          10325                Red Moon
# 2       6.5        48215          10325  Black Horse Black Beer
# 3       5.0        47969          10325              Sausa Pils
# 4       7.7        64883           1075           Cauldron DIPA
# 5       4.7        52159           1075     Caldera Ginger Beer
# 6       4.7        52159           1075     Caldera Ginger Beer
# 7       4.7        52159           1075     Caldera Ginger Beer
# 8       4.7        52159           1075     Caldera Ginger Beer
# 9       4.7        52159           1075     Caldera Ginger Beer
#
#                        beer_style  review_appearance  review_palette  \
# 0                      Hefeweizen                2.5             2.0
# 1              English Strong Ale                3.0             2.5
# ...
