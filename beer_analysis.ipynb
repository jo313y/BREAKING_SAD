# %%
import pandas as pd

# %%
beer_df = pd.read_csv('BeerProject.csv')
beer_df
# Out:
#         beer_ABV  beer_beerId  beer_brewerId               beer_name  \
# 0            5.0        47986          10325            Sausa Weizen
# 1            6.2        48213          10325                Red Moon
# 2            6.5        48215          10325  Black Horse Black Beer
# 3            5.0        47969          10325              Sausa Pils
# 4            7.7        64883           1075           Cauldron DIPA
# ...          ...          ...            ...                     ...
# 528865       NaN         4032           3340       Dinkel Acker Dark
# 528866       NaN         4032           3340       Dinkel Acker Dark
# 528867       NaN         4032           3340       Dinkel Acker Dark
# 528868       NaN         4032           3340       Dinkel Acker Dark
# 528869       NaN         4032           3340       Dinkel Acker Dark
#
#                             beer_style  review_appearance  review_palette  \
# ...

# %%
beer_df.dtypes
# Out:
# beer_ABV              float64
# beer_beerId             int64
# beer_brewerId           int64
# beer_name              object
# beer_style             object
# review_appearance     float64
# review_palette        float64
# review_overall        float64
# review_taste          float64
# review_profileName     object
# review_aroma          float64
# review_text            object
# review_time             int64
# dtype: object

# %%
print("\n----------- Minimum -----------\n")
print(beer_df[['beer_ABV', 'review_appearance', 'review_palette', 'review_overall', 'review_taste', 'review_aroma']].min())

print("\n----------- Max -----------\n")
print(beer_df[['beer_ABV', 'review_appearance', 'review_palette', 'review_overall', 'review_taste', 'review_aroma']].max())
# Out:
# ----------- Minimum -----------
#
# beer_ABV             0.01
# review_appearance    0.00
# review_palette       1.00
# review_overall       0.00
# review_taste         1.00
# review_aroma         1.00
# dtype: float64
#
# ----------- Max -----------
#
# beer_ABV             57.7
# review_appearance     5.0
# review_palette        5.0
# review_overall        5.0
# review_taste          5.0
# review_aroma          5.0
# dtype: float64

# %%
beer_dropped_cols = beer_df.drop(columns=['review_time', 'review_text'])
beer_dropped_cols
# Out:
#         beer_ABV  beer_beerId  beer_brewerId               beer_name  \
# 0            5.0        47986          10325            Sausa Weizen
# 1            6.2        48213          10325                Red Moon
# 2            6.5        48215          10325  Black Horse Black Beer
# 3            5.0        47969          10325              Sausa Pils
# 4            7.7        64883           1075           Cauldron DIPA
# ...          ...          ...            ...                     ...
# 528865       NaN         4032           3340       Dinkel Acker Dark
# 528866       NaN         4032           3340       Dinkel Acker Dark
# 528867       NaN         4032           3340       Dinkel Acker Dark
# 528868       NaN         4032           3340       Dinkel Acker Dark
# 528869       NaN         4032           3340       Dinkel Acker Dark
#
#                             beer_style  review_appearance  review_palette  \
# ...

# %%
clean_beer = beer_dropped_cols.dropna()
clean_beer
# Out:
#         beer_ABV  beer_beerId  beer_brewerId               beer_name  \
# 0            5.0        47986          10325            Sausa Weizen
# 1            6.2        48213          10325                Red Moon
# 2            6.5        48215          10325  Black Horse Black Beer
# 3            5.0        47969          10325              Sausa Pils
# 4            7.7        64883           1075           Cauldron DIPA
# ...          ...          ...            ...                     ...
# 528792       5.1        29915           3340  Dinkelacker Goldh�lsle
# 528793       5.1        29915           3340  Dinkelacker Goldh�lsle
# 528794       4.9        32658           3340        Schwaben Pilsner
# 528795       4.9        32658           3340        Schwaben Pilsner
# 528796       4.9        32658           3340        Schwaben Pilsner
#
#                             beer_style  review_appearance  review_palette  \
# ...

# %%
clean_beer.describe()
# Out:
#             beer_ABV    beer_beerId  beer_brewerId  review_appearance  \
# count  508475.000000  508475.000000  508475.000000      508475.000000
# mean        7.017467   21822.790013    2534.078684           3.872699
# std         2.204484   22124.321330    5237.579622           0.601774
# min         0.010000       5.000000       1.000000           0.000000
# 25%         5.300000    1673.000000     132.000000           3.500000
# 50%         6.500000   13838.000000     392.000000           4.000000
# 75%         8.500000   40418.000000    1315.000000           4.000000
# max        57.700000   77310.000000   27980.000000           5.000000
#
#        review_palette  review_overall   review_taste   review_aroma
# count   508475.000000   508475.000000  508475.000000  508475.000000
# mean         3.769016        3.840857       3.775375       3.827686
# std          0.682371        0.706407       0.665587       0.715133
# ...

# %%
file_path = '/Users/e1/Desktop/Class Folder/BREAKING_SAD/clean_beer.csv'
clean_beer.to_csv(file_path, index=False)
